# %%
import pandas

# %%
pandas.read_csv("commute_data.csv")
# Out:
#       Unnamed: 0  EmployeeNumber  DistanceFromHome
# 0              1               1                 1
# 1              2               2                 8
# 2              3               4                 2
# 3              4               5                 3
# 4              5               7                 2
# 5              6               8                 2
# 6              7              10                 3
# 7              8              11                24
# 8              9              12                23
# 9             10              13                27
# 10            11              14                16
# 11            12              15                15
# 12            13              16                26
# 13            14              18                19
# 14            15              19                24
# 15            16              20                21
# 16            17              21                 5
# ...

# %%
pandas.read_csv("hr_employees_performance_data.csv")
# Out:
#     Unnamed: 0     BusinessTravel  DailyRate  EmployeeNumber  \
# 0            1      Travel_Rarely        945             103
# 1            2      Travel_Rarely        807             133
# 2            3         Non-Travel       1420             140
# 3            4         Non-Travel        142             148
# 4            5      Travel_Rarely       1355             177
# 5            6      Travel_Rarely       1240             184
# 6            7      Travel_Rarely        818             321
# 7            8      Travel_Rarely        106             424
# 8            9      Travel_Rarely        544             470
# 9           10      Travel_Rarely        489             566
# 10          11  Travel_Frequently        988             590
# 11          12  Travel_Frequently        426             608
# 12          13  Travel_Frequently       1246             644
# 13          14      Travel_Rarely       1112             665
# ...

# %%
pandas.read_csv("personal_data.csv")
# Out:
#        EmployeeNumber   Variable   Value
# 0                   1     Gender  Female
# 1                   2     Gender    Male
# 2                   4     Gender    Male
# 3                   5     Gender  Female
# 4                   7     Gender    Male
# 5                   8     Gender    Male
# 6                  10     Gender  Female
# 7                  11     Gender    Male
# 8                  12     Gender    Male
# 9                  13     Gender    Male
# 10                 14     Gender    Male
# 11                 15     Gender  Female
# 12                 16     Gender    Male
# 13                 18     Gender    Male
# 14                 19     Gender    Male
# 15                 20     Gender  Female
# 16                 21     Gender    Male
# 17                 22     Gender    Male
# 18                 23     Gender  Female
# 19                 24     Gender    Male
# 20                 26     Gender  Female
# 21                 27     Gender    Male
# ...

# %%
pandas.read_csv("research_and_development_employees_performance_data.csv")
# Out:
#      Unnamed: 0     BusinessTravel  DailyRate  EmployeeNumber  \
# 0             1  Travel_Frequently        279               2
# 1             2      Travel_Rarely       1373               4
# 2             3  Travel_Frequently       1392               5
# 3             4      Travel_Rarely        591               7
# 4             5  Travel_Frequently       1005               8
# 5             6      Travel_Rarely       1324              10
# 6             7      Travel_Rarely       1358              11
# 7             8  Travel_Frequently        216              12
# 8             9      Travel_Rarely       1299              13
# 9            10      Travel_Rarely        809              14
# 10           11      Travel_Rarely        153              15
# 11           12      Travel_Rarely        670              16
# 12           13      Travel_Rarely       1346              18
# 13           14      Travel_Rarely        103              19
# ...

# %%
pandas.read_csv("sales_employees_performance_data.csv")
# Out:
#      Unnamed: 0     BusinessTravel  DailyRate  EmployeeNumber  \
# 0             1      Travel_Rarely       1102               1
# 1             2      Travel_Rarely       1219              23
# 2             3      Travel_Rarely       1218              27
# 3             4      Travel_Rarely        691              35
# 4             5      Travel_Rarely        705              38
# 5             6      Travel_Rarely        895              42
# 6             7      Travel_Rarely        869              47
# 7             8      Travel_Rarely        890              49
# 8             9  Travel_Frequently       1141              52
# 9            10  Travel_Frequently        994              56
# 10           11         Non-Travel       1065              60
# 11           12  Travel_Frequently       1211              62
# 12           13      Travel_Rarely       1488              68
# 13           14      Travel_Rarely       1443              72
# ...
