# %%
import os
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'C2ImportCalEventSample.csv',
#  'C2ImportFamRelSample.csv',
#  'C2ImportGroupsSample.csv',
#  'csv_files.ipynb',
#  'testings.ipynb']

# %%
import os
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'C2ImportCalEventSample.csv',
#  'C2ImportFamRelSample.csv',
#  'C2ImportGroupsSample.csv',
#  'csv_files.ipynb',
#  'testings.ipynb']

# %%
import os
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'C2ImportCalEventSample.csv',
#  'C2ImportFamRelSample.csv',
#  'C2ImportGroupsSample.csv',
#  'csv_files.ipynb',
#  'testings.ipynb']

# %%
import pandas
df1 = pandas.read_csv("C2ImportCalEventSample.csv")
df1
# Out:
#   Start Date   Start Time  End Date    End Time                  Event Title   \
# 0    9/5/2011  3:00:00 PM  9/5/2011         NaN  Social Studies Dept. Meeting
# 1    9/5/2011  6:00:00 PM  9/5/2011  8:00:00 PM            Curriculum Meeting
#
#   All Day Event No End Time   Event Description         Contact   \
# 0             N           Y  Department meeting  Chris Gallagher
# 1             N           N  Curriculum Meeting  Chris Gallagher
#
#                 Contact Email Contact Phone     Location  Category Mandatory  \
# 0  cgallagher@schoolwires.com  814-555-5179  High School         2         N
# 1  cgallagher@schoolwires.com  814-555-5179  High School         2         N
#
#   Registration  Maximum Last Date To Register
# 0            N       25              9/2/2011
# 1            N       25              9/2/2011

# %%
df1 = pandas.read_csv("C2ImportFamRelSample.csv")
df1
# Out:
#    Parent Identifier  Student Identifier
# 0               1001                1002
# 1               1010                1020

# %%
df1 = pandas.read_csv("C2ImportGroupsSample.csv")
df1
# Out:
#                         GroupName     Groupcode   GroupOwner  GroupCategoryID
# 0           System Administrators       sysadmin     13456.0               100
# 1      Independence High Teachers    HS Teachers         NaN               101
# 2      John Glenn Middle Teachers    MS Teachers     13458.0               102
# 3     Liberty Elementary Teachers  Elem Teachers     13559.0               103
# 4              1st Grade Teachers       1stgrade         NaN               104
# 5              2nd Grade Teachers       2nsgrade     13561.0               105
# 6              3rd Grade Teachers       3rdgrade     13562.0               106
# 7             Guidance Department       guidance         NaN               107
# 8      Independence Math Teachers        HS Math     13660.0               108
# 9   Independence English Teachers     HS English     13661.0               109
# 10  John Glenn 8th Grade Teachers       8thgrade         NaN               110
# ...

# %%
df1.set_index("GroupName")
# Out:
#                                   Groupcode   GroupOwner  GroupCategoryID
# GroupName
# System Administrators               sysadmin     13456.0               100
# Independence High Teachers       HS Teachers         NaN               101
# John Glenn Middle Teachers       MS Teachers     13458.0               102
# Liberty Elementary Teachers    Elem Teachers     13559.0               103
# 1st Grade Teachers                  1stgrade         NaN               104
# 2nd Grade Teachers                  2nsgrade     13561.0               105
# 3rd Grade Teachers                  3rdgrade     13562.0               106
# Guidance Department                 guidance         NaN               107
# Independence Math Teachers           HS Math     13660.0               108
# Independence English Teachers     HS English     13661.0               109
# John Glenn 8th Grade Teachers       8thgrade         NaN               110
# ...

# %%
df1.shape
# Out:
# (15, 4)

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  '095 supermarkets.json',
#  'C2ImportCalEventSample.csv',
#  'C2ImportFamRelSample.csv',
#  'C2ImportGroupsSample.csv',
#  'csv_files.ipynb',
#  'testings.ipynb']

# %%
df1= pandas.read_json("095 supermarkets.json")
df1
# Out:
#            Address           City Country  Employees  ID         Name  \
# 0     3666 21st St  San Francisco     USA          8   1      Madeira
# 1   735 Dolores St  San Francisco     USA         15   2  Bready Shop
# 2      332 Hill St  San Francisco     USA         25   3  Super River
# 3     3995 23rd St  San Francisco     USA         10   4   Ben's Shop
# 4  1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 5  551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#               State
# 0          CA 94114
# 1          CA 94119
# 2  California 94114
# 3          CA 94114
# 4        California
# 5          CA 94114

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  '095 supermarkets.json',
#  'C2ImportCalEventSample.csv',
#  'C2ImportFamRelSample.csv',
#  'C2ImportGroupsSample.csv',
#  'csv_files.ipynb',
#  'king-james-bible.xlsm',
#  'meetingbingo.xls',
#  'testings.ipynb',
#  'word clock.xlsm']

# %%
word clock.xlsmdf3= pandas.read_excel("king-james-bible.xlsm")
df3
# Out:
#     Unnamed: 0                         King James Bible\nIn Excel  \
# 0          NaN                                      Old Testament
# 1          NaN                                            Genesis
# 2          NaN                                             Exodus
# 3          NaN                                          Leviticus
# 4          NaN                                            Numbers
# 5          NaN                                        Deuteronomy
# 6          NaN                                             Joshua
# 7          NaN                                             Judges
# 8          NaN                                               Ruth
# 9          NaN                                           1 Samuel
# 10         NaN                                           2 Samuel
# 11         NaN                                            1 Kings
# 12         NaN                                            2 Kings
# ...

# %%
df3= pandas.read_excel("king-james-bible.xlsm", sheet_name = 0)
df3
# Out:
#     Unnamed: 0                         King James Bible\nIn Excel  \
# 0          NaN                                      Old Testament
# 1          NaN                                            Genesis
# 2          NaN                                             Exodus
# 3          NaN                                          Leviticus
# 4          NaN                                            Numbers
# 5          NaN                                        Deuteronomy
# 6          NaN                                             Joshua
# 7          NaN                                             Judges
# 8          NaN                                               Ruth
# 9          NaN                                           1 Samuel
# 10         NaN                                           2 Samuel
# 11         NaN                                            1 Kings
# 12         NaN                                            2 Kings
# ...

# %%
df3= pandas.read_excel("meetingbingo.xls", sheet_name = 1)
df3
# Out:
#    Press F9 to generate a new card.  Unnamed: 1                 Unnamed: 2  \
# 0                               NaN         NaN  M E E T I N G   B I N G O
# 1                               NaN         NaN     TRANSITION (AS A VERB)
# 2                               NaN         NaN              HIGH PRIORITY
# 3                               NaN         NaN            RISK MANAGEMENT
# 4                               NaN         NaN                  REPURPOSE
# 5                               NaN         NaN                  DIVERSITY
#
#        Unnamed: 3     Unnamed: 4        Unnamed: 5            Unnamed: 6
# 0             NaN            NaN               NaN                   NaN
# 1     IN THE LOOP     TASK FORCE   ENTERPRISE WIDE     MULTIDISCIPLINARY
# 2     ALTERNATIVE   BENCHMARKING       METHODOLOGY  SERVICE ORGANIZATION
# 3    RUBBER STAMP  STRATEGIC GAP  TOP OF THE HOUSE            FLATTENING
# 4  CLIENT-FOCUSED        WIN-WIN        PRODUCTIZE      MISSION CRITICAL
# ...

# %%
df3= pandas.read_excel("word clock.xlsm", sheet_name = 2)
df3
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-24-237eb172c9aa> in <module>()
# ----> 1 df3= pandas.read_excel("word clock.xlsm", sheet_name = 2)
#       2 df3
#
# c:\program files (x86)\python36-32\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     175                 else:
#     176                     kwargs[new_arg_name] = new_arg_value
# --> 177             return func(*args, **kwargs)
#     178         return wrapper
#     179     return _deprecate_kwarg
#
# c:\program files (x86)\python36-32\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     175                 else:
#     176                     kwargs[new_arg_name] = new_arg_value
# --> 177             return func(*args, **kwargs)
#     178         return wrapper
#     179     return _deprecate_kwarg
#
# ...

# %%
df4 = pandas.read_csv("pra.txt")
df4
# Out:
#           pear
# 0        apple
# 1       orange
# 2     mandarin
# 3   watermelon
# 4  pomegranate

# %%
df4 = pandas.read_csv("pra.txt")
df4
# Out:
#           pear
# 0        apple
# 1       orange
# 2     mandarin
# 3   watermelon
# 4  pomegranate

# %%
import pandas
df6= pandas.read_json("http://pythonhow.com/supermarkets.json")
df6
# Out:
#            Address           City Country  Employees  ID         Name  \
# 0     3666 21st St  San Francisco     USA          8   1      Madeira
# 1   735 Dolores St  San Francisco     USA         15   2  Bready Shop
# 2      332 Hill St  San Francisco     USA         25   3  Super River
# 3     3995 23rd St  San Francisco     USA         10   4   Ben's Shop
# 4  1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 5  551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#               State
# 0          CA 94114
# 1          CA 94119
# 2  California 94114
# 3          CA 94114
# 4        California
# 5          CA 94114

# %%
df6.set_index?

# %%
df6.loc["3666 21st St":"332 Hill St", "ID":"State"]
# Out:
# Empty DataFrame
# Columns: [ID, Name, State]
# Index: []

# %%
df6.loc["3666 21st St":"3995 23rd St"  ,   "City":"Country"]
# Out:
# Empty DataFrame
# Columns: [City, Country]
# Index: []

# %%
import pandas

# %%
df7= pandas.read_json("http://pythonhow.com/supermarkets.json")
df7
# Out:
#            Address           City Country  Employees  ID         Name  \
# 0     3666 21st St  San Francisco     USA          8   1      Madeira
# 1   735 Dolores St  San Francisco     USA         15   2  Bready Shop
# 2      332 Hill St  San Francisco     USA         25   3  Super River
# 3     3995 23rd St  San Francisco     USA         10   4   Ben's Shop
# 4  1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 5  551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#               State
# 0          CA 94114
# 1          CA 94119
# 2  California 94114
# 3          CA 94114
# 4        California
# 5          CA 94114

# %%
df7.loc[0:3,"ID":"State"]
# Out:
#    ID         Name             State
# 0   1      Madeira          CA 94114
# 1   2  Bready Shop          CA 94119
# 2   3  Super River  California 94114
# 3   4   Ben's Shop          CA 94114

# %%
df7
# Out:
#            Address           City Country  Employees  ID         Name  \
# 0     3666 21st St  San Francisco     USA          8   1      Madeira
# 1   735 Dolores St  San Francisco     USA         15   2  Bready Shop
# 2      332 Hill St  San Francisco     USA         25   3  Super River
# 3     3995 23rd St  San Francisco     USA         10   4   Ben's Shop
# 4  1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 5  551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#               State
# 0          CA 94114
# 1          CA 94119
# 2  California 94114
# 3          CA 94114
# 4        California
# 5          CA 94114

# %%
df7.loc[]
# Out:
# "Ben's Shop"

# %%
df7
# Out:
#            Address           City Country  Employees  ID         Name  \
# 0     3666 21st St  San Francisco     USA          8   1      Madeira
# 1   735 Dolores St  San Francisco     USA         15   2  Bready Shop
# 2      332 Hill St  San Francisco     USA         25   3  Super River
# 3     3995 23rd St  San Francisco     USA         10   4   Ben's Shop
# 4  1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 5  551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#               State
# 0          CA 94114
# 1          CA 94119
# 2  California 94114
# 3          CA 94114
# 4        California
# 5          CA 94114

# %%
df7.drop("City",1)
# Out:
#            Address Country  Employees  ID         Name             State
# 0     3666 21st St     USA          8   1      Madeira          CA 94114
# 1   735 Dolores St     USA         15   2  Bready Shop          CA 94119
# 2      332 Hill St     USA         25   3  Super River  California 94114
# 3     3995 23rd St     USA         10   4   Ben's Shop          CA 94114
# 4  1056 Sanchez St     USA         12   5      Sanchez        California
# 5  551 Alvarado St     USA         20   6   Richvalley          CA 94114

# %%
df7
# Out:
#            Address           City Country  Employees  ID         Name  \
# 0     3666 21st St  San Francisco     USA          8   1      Madeira
# 1   735 Dolores St  San Francisco     USA         15   2  Bready Shop
# 2      332 Hill St  San Francisco     USA         25   3  Super River
# 3     3995 23rd St  San Francisco     USA         10   4   Ben's Shop
# 4  1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 5  551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#               State
# 0          CA 94114
# 1          CA 94119
# 2  California 94114
# 3          CA 94114
# 4        California
# 5          CA 94114

# %%
df7.drop(0,0)
# Out:
#            Address           City Country  Employees  ID         Name  \
# 1   735 Dolores St  San Francisco     USA         15   2  Bready Shop
# 2      332 Hill St  San Francisco     USA         25   3  Super River
# 3     3995 23rd St  San Francisco     USA         10   4   Ben's Shop
# 4  1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 5  551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#               State
# 1          CA 94119
# 2  California 94114
# 3          CA 94114
# 4        California
# 5          CA 94114

# %%
df7.drop(df7.index[0:3],0)
# Out:
#            Address           City Country  Employees  ID        Name  \
# 3     3995 23rd St  San Francisco     USA         10   4  Ben's Shop
# 4  1056 Sanchez St  San Francisco     USA         12   5     Sanchez
# 5  551 Alvarado St  San Francisco     USA         20   6  Richvalley
#
#         State
# 3    CA 94114
# 4  California
# 5    CA 94114

# %%
ddf7
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-e67f78e0e98b> in <module>()
# ----> 1 ddf7
#
# NameError: name 'ddf7' is not defined

# %%
df7
# Out:
#            Address           City Country  Employees  ID         Name  \
# 0     3666 21st St  San Francisco     USA          8   1      Madeira
# 1   735 Dolores St  San Francisco     USA         15   2  Bready Shop
# 2      332 Hill St  San Francisco     USA         25   3  Super River
# 3     3995 23rd St  San Francisco     USA         10   4   Ben's Shop
# 4  1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 5  551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#               State
# 0          CA 94114
# 1          CA 94119
# 2  California 94114
# 3          CA 94114
# 4        California
# 5          CA 94114

# %%
df7.shape
# Out:
# (6, 7)

# %%
df7.shape[0]*["North America"]
# Out:
# ['North America',
#  'North America',
#  'North America',
#  'North America',
#  'North America',
#  'North America']

# %%
df7["Surname"] = df7.shape[1]*["Ladva"]
df7
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-40-2d433bcbec40> in <module>()
# ----> 1 df7["Surname"] = df7.shape[1]*["Ladva"]
#       2 df7
#
# c:\program files (x86)\python36-32\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3114         else:
#    3115             # set column
# -> 3116             self._set_item(key, value)
#    3117
#    3118     def _setitem_slice(self, key, value):
#
# c:\program files (x86)\python36-32\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    3189
#    3190         self._ensure_valid_index(value)
# -> 3191         value = self._sanitize_column(key, value)
#    3192         NDFrame._set_item(self, key, value)
#    3193
#
# c:\program files (x86)\python36-32\lib\site-packages\pandas\core\frame.py in _sanitize_column(self, key, value, broadcast)
#    3386
# ...

# %%
df7
# Out:
#            Address           City Country  Employees  ID         Name  \
# 0     3666 21st St  San Francisco     USA          8   1      Madeira
# 1   735 Dolores St  San Francisco     USA         15   2  Bready Shop
# 2      332 Hill St  San Francisco     USA         25   3  Super River
# 3     3995 23rd St  San Francisco     USA         10   4   Ben's Shop
# 4  1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 5  551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#               State Surname
# 0          CA 94114   Ladva
# 1          CA 94119   Ladva
# 2  California 94114   Ladva
# 3          CA 94114   Ladva
# 4        California   Ladva
# 5          CA 94114   Ladva

# %%
df7["Surname"] = df7.shape[1]*["Ladva"]
df7
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-41-2d433bcbec40> in <module>()
# ----> 1 df7["Surname"] = df7.shape[1]*["Ladva"]
#       2 df7
#
# c:\program files (x86)\python36-32\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3114         else:
#    3115             # set column
# -> 3116             self._set_item(key, value)
#    3117
#    3118     def _setitem_slice(self, key, value):
#
# c:\program files (x86)\python36-32\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    3189
#    3190         self._ensure_valid_index(value)
# -> 3191         value = self._sanitize_column(key, value)
#    3192         NDFrame._set_item(self, key, value)
#    3193
#
# c:\program files (x86)\python36-32\lib\site-packages\pandas\core\frame.py in _sanitize_column(self, key, value, broadcast)
#    3386
# ...

# %%
df7["Continent"] = df7["Country"] + "," + "North America"

# %%
df7
# Out:
#            Address           City Country  Employees  ID         Name  \
# 0     3666 21st St  San Francisco     USA          8   1      Madeira
# 1   735 Dolores St  San Francisco     USA         15   2  Bready Shop
# 2      332 Hill St  San Francisco     USA         25   3  Super River
# 3     3995 23rd St  San Francisco     USA         10   4   Ben's Shop
# 4  1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 5  551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#               State Surname          Continent
# 0          CA 94114   Ladva  USA,North America
# 1          CA 94119   Ladva  USA,North America
# 2  California 94114   Ladva  USA,North America
# 3          CA 94114   Ladva  USA,North America
# 4        California   Ladva  USA,North America
# 5          CA 94114   Ladva  USA,North America

# %%
df7
# Out:
#            Address           City Country  Employees  ID         Name  \
# 0     3666 21st St  San Francisco     USA          8   1      Madeira
# 1   735 Dolores St  San Francisco     USA         15   2  Bready Shop
# 2      332 Hill St  San Francisco     USA         25   3  Super River
# 3     3995 23rd St  San Francisco     USA         10   4   Ben's Shop
# 4  1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 5  551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#               State Surname          Continent
# 0          CA 94114   Ladva  USA,North America
# 1          CA 94119   Ladva  USA,North America
# 2  California 94114   Ladva  USA,North America
# 3          CA 94114   Ladva  USA,North America
# 4        California   Ladva  USA,North America
# 5          CA 94114   Ladva  USA,North America

# %%
df7_t=df7.T
df7_t
# Out:
#                            0                  1                  2  \
# Address         3666 21st St     735 Dolores St        332 Hill St
# City           San Francisco      San Francisco      San Francisco
# Country                  USA                USA                USA
# Employees                  8                 15                 25
# ID                         1                  2                  3
# Name                 Madeira        Bready Shop        Super River
# State               CA 94114           CA 94119   California 94114
# Surname                Ladva              Ladva              Ladva
# Continent  USA,North America  USA,North America  USA,North America
#
#                            3                  4                  5
# Address         3995 23rd St    1056 Sanchez St    551 Alvarado St
# City           San Francisco      San Francisco      San Francisco
# Country                  USA                USA                USA
# ...

# %%
df7_t[6]=["Sg Highway", "Ahmedabad", "India", 2000,  1, "Manthan", "Gujarat",  "Ladva", "Asia"]

# %%
df7_t
# Out:
#                            0                  1                  2  \
# Address         3666 21st St     735 Dolores St        332 Hill St
# City           San Francisco      San Francisco      San Francisco
# Country                  USA                USA                USA
# Employees                  8                 15                 25
# ID                         1                  2                  3
# Name                 Madeira        Bready Shop        Super River
# State               CA 94114           CA 94119   California 94114
# Surname                Ladva              Ladva              Ladva
# Continent  USA,North America  USA,North America  USA,North America
#
#                            3                  4                  5           6
# Address         3995 23rd St    1056 Sanchez St    551 Alvarado St  Sg Highway
# City           San Francisco      San Francisco      San Francisco   Ahmedabad
# ...

# %%
df7=df7_t.T
df7
# Out:
#            Address           City Country Employees ID         Name  \
# 0     3666 21st St  San Francisco     USA         8  1      Madeira
# 1   735 Dolores St  San Francisco     USA        15  2  Bready Shop
# 2      332 Hill St  San Francisco     USA        25  3  Super River
# 3     3995 23rd St  San Francisco     USA        10  4   Ben's Shop
# 4  1056 Sanchez St  San Francisco     USA        12  5      Sanchez
# 5  551 Alvarado St  San Francisco     USA        20  6   Richvalley
# 6       Sg Highway      Ahmedabad   India      2000  1      Manthan
#
#               State Surname          Continent
# 0          CA 94114   Ladva  USA,North America
# 1          CA 94119   Ladva  USA,North America
# 2  California 94114   Ladva  USA,North America
# 3          CA 94114   Ladva  USA,North America
# 4        California   Ladva  USA,North America
# 5          CA 94114   Ladva  USA,North America
# 6           Gujarat   Ladva               Asia

# %%
import geopy

# %%
dir(geopy)
# Out:
# ['ArcGIS',
#  'Baidu',
#  'Bing',
#  'DataBC',
#  'GeoNames',
#  'GeocodeFarm',
#  'GoogleV3',
#  'IGNFrance',
#  'LiveAddress',
#  'Location',
#  'Mapzen',
#  'Nominatim',
#  'OpenCage',
#  'OpenMapQuest',
#  'Photon',
#  'PickPoint',
#  'Point',
#  'What3Words',
#  'Yandex',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  'compat',
#  'exc',
#  'format',
#  'geocoders',
#  'get_geocoder_for_service',
#  'location',
#  'point',
#  'units',
#  'util']

# %%
from geopy.geocoders import Nominatim

# %%
nom = Nominatim()

# %%
n=nom.geocode("Ankur Chokadi, New India Colony, Nikol, Ahmedabad, Gujarat 380038, India")
print(n)
# Out:
# None

# %%
import pandas
df = pandas.read_csv("supermarkets.csv")
df
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df["Address"] = df["Address"] + ","+  df["City"]+ "," + df["State"]+ ","+ df["Country"]
df
# Out:
#    ID                                         Address           City  \
# 0   1         3666 21st St,San Francisco,CA 94114,USA  San Francisco
# 1   2       735 Dolores St,San Francisco,CA 94119,USA  San Francisco
# 2   3  332 Hill St,San Francisco,California 94114,USA  San Francisco
# 3   4         3995 23rd St,San Francisco,CA 94114,USA  San Francisco
# 4   5    1056 Sanchez St,San Francisco,California,USA  San Francisco
# 5   6      551 Alvarado St,San Francisco,CA 94114,USA  San Francisco
#
#               State Country         Name  Employees
# 0          CA 94114     USA      Madeira          8
# 1          CA 94119     USA  Bready Shop         15
# 2  California 94114     USA  Super River         25
# 3          CA 94114     USA   Ben's Shop         10
# 4        California     USA      Sanchez         12
# 5          CA 94114     USA   Richvalley         20

# %%
df["Coordinates"] = df["Address"] .apply(nom.geocode)
df
# Out:
#    ID                                         Address           City  \
# 0   1         3666 21st St,San Francisco,CA 94114,USA  San Francisco
# 1   2       735 Dolores St,San Francisco,CA 94119,USA  San Francisco
# 2   3  332 Hill St,San Francisco,California 94114,USA  San Francisco
# 3   4         3995 23rd St,San Francisco,CA 94114,USA  San Francisco
# 4   5    1056 Sanchez St,San Francisco,California,USA  San Francisco
# 5   6      551 Alvarado St,San Francisco,CA 94114,USA  San Francisco
#
#               State Country         Name  Employees  \
# 0          CA 94114     USA      Madeira          8
# 1          CA 94119     USA  Bready Shop         15
# 2  California 94114     USA  Super River         25
# 3          CA 94114     USA   Ben's Shop         10
# 4        California     USA      Sanchez         12
# 5          CA 94114     USA   Richvalley         20
#
#                                          Coordinates
# 0  (3666, 21st Street, Noe Valley, SF, California...
# ...

# %%
df.Coordinates[5].latitude
# Out:
# 37.7536733265306

# %%
df["Latitude"] = df["Coordinates"].apply(lambda x: x.latitude is x )
